# %%
# Code implemented from : https://github.com/tansey/deep-dose-response/tree/master

"""Dose-Response Modeling in High-Throughput Cancer Drug Screenings: An end-to-end approach
W. Tansey, K. Li, H. Zhang, S. W. Linderman, D. M. Blei, R. Rabadan, and C. H. Wiggins
Preprint, December 2018. https://arxiv.org/abs/1812.05691"""

# %%
import os
import sys
import random
import numpy as np
import pandas as pd
import pickle as pkl
import matplotlib.pyplot as plt
import math
import seaborn as sns

from scipy.special import gammaln, gammaincc
from scipy.stats import gamma, poisson
from scipy.optimize import minimize
from scipy.stats import invwishart, poisson, multivariate_normal as mvn

# %%
raw_data = pd.read_csv("/content/GDSC2_public_raw_data_27Oct23.csv")
pos_ctrl_priors = np.load("/content/pos-ctrl-priors.npz")
neg_ctrl_priors = np.load("/content/neg-ctrl-priors.npz")

# %%
def ilogit(x):
    #print("Input to ilogit:", x, "Type:", type(x))  # Debugging line
    return 1. / (1 + np.exp(-x))

"""def monotone_rejection_sampler(m, Sigma):
    beta = np.random.multivariate_normal(m, Sigma)
    while np.any(beta[:-1] > beta[1:]):
        beta = np.random.multivariate_normal(m, Sigma)
    return beta"""

def monotone_rejection_sampler(m, Sigma, index=None):
    attempts = 0
    beta = np.random.multivariate_normal(m, Sigma)
    while np.any(beta[:-1] > beta[1:]):
        beta = np.random.multivariate_normal(m, Sigma)
        attempts += 1
    print(f"Row {index}: Completed after {attempts + 1} attempts")
    return beta

# %%
from logging import raiseExceptions
def elliptical_slice(xx, prior, log_like_fn, cur_log_like = None, angle_range = 0, ll_args = None, mu = None):
  xx = np.copy(xx)
  D = np.size(xx)
  print("xx size: ", np.shape(xx),
        "prior size: ", np.shape(prior))
  if np.size(prior) == D:
    nu = np.reshape(prior, (D,))
  else:
    if np.shape(prior)!=(D,D):
      raise Exception("Prior must be given by a D-element sample")
    nu = np.reshape(np.dot(prior, np.random.randn(D,1)).T, np.shape(xx))
  if mu is None:
    mu = np.zeros(D)
  elif np.size(mu)!=D:
    raise Exception("Speicifed mean does not have the correct shape")

  if (cur_log_like is None):
    #cur_log_like = log_like_fn(xx, ll_args)
    cur_log_like = log_like_fn(xx)
  init_ll = cur_log_like
  hh = np.log(np.random.rand()) + cur_log_like

  #set up the bracket of angles and pick first proposal
  # phi = theta' - theta is a change in angle
  if angle_range <= 0:
    phi = np.random.rand() * 2 * math.pi
    phi_min = phi - 2*math.pi
    phi_max = phi
  else:
    phi_min = -1 * angle_range * np.random.rand()
    phi_max = phi_min + angle_range
    phi = np.random.rand() * (phi_max - phi_min) + phi_min

  check=0
  while True:
    #compute xx for proposed angle difference and check if it's on the slice
    #Add the offset mu before computing the likelihood
    xx_prop = ((xx-mu)*np.cos(phi)) + nu*np.sin(phi) + mu
    #cur_log_like = log_like_fn(xx_prop, ll_args)
    cur_log_like = log_like_fn(xx_prop)
    """
    if check%20==0:
      print(f"Proposed beta: {xx_prop}, log likelihood: {cur_log_like}")
    """
    if cur_log_like >= hh:
      print(f"Accepted new beta")
      break

    #shrink slice to rejected point
    if phi>0:
      phi_max = phi
    elif phi < 0:
      phi_min = phi
    else:
      import warnings
      assert np.allclose(xx, xx_prop)
      warnings.warn("Shrug to current position and stil rejected")
      break

    phi = np.random.rand()*(phi_max - phi_min) + phi_min
    check+=1

  return xx_prop, cur_log_like

# %%
unique_barcodes = raw_data['BARCODE'].unique()

M = np.full((len(unique_barcodes), 7), np.nan)
Y = np.full((len(unique_barcodes), 7), np.nan)

for i, barcode in enumerate(unique_barcodes):
    barcode_data = raw_data[raw_data['BARCODE'] == barcode]

    # Iterate over each dose level (1 to 7)
    for dose_level in range(1, 8):
        # Build the TAG pattern for the current dose level
        tag_pattern = f'D{dose_level}-S'

        dose_data = barcode_data[barcode_data['TAG'].str.contains(tag_pattern, na=False)]

        if not dose_data.empty:
            M[i, dose_level - 1] = dose_data['CONC'].values[0]  # Concentration
            Y[i, dose_level - 1] = dose_data['INTENSITY'].values[0]  # Intensity

# %%
raw_barcodes = list(set(unique_barcodes))

# %%
M_df = pd.DataFrame(M, index=unique_barcodes, columns=[f'Dose_{i}' for i in range(1, 8)])
Y_df = pd.DataFrame(Y, index=unique_barcodes, columns=[f'Dose_{i}' for i in range(1, 8)])

M_df.index.name = 'BARCODE'
Y_df.index.name = 'BARCODE'

M_df.to_csv('/content/M_df.csv')
Y_df.to_csv('/content/Y_df.csv')

# %%
A = pos_ctrl_priors["a"]
B = pos_ctrl_priors["b"]
C = neg_ctrl_priors["c"]

# %%
drug_to_barcodes = raw_data.groupby('DRUG_ID')['BARCODE'].apply(list)

# %%
filtered_data = raw_data[raw_data['DRUG_ID'].notna()]

unique_barcodes_drug = filtered_data['BARCODE'].unique()

# %%
# subset 100 barcodes to check the code
selected_barcodes = np.random.choice(unique_barcodes_drug, 30, replace=False)
A_full = pd.DataFrame({'BARCODE': pos_ctrl_priors['barcodes'], 'A': pos_ctrl_priors['a']}).set_index('BARCODE')
B_full = pd.DataFrame({'BARCODE': pos_ctrl_priors['barcodes'], 'B': pos_ctrl_priors['b']}).set_index('BARCODE')
C_full = pd.DataFrame({'BARCODE': neg_ctrl_priors['barcodes'], 'C': neg_ctrl_priors['c']}).set_index('BARCODE')

A_subset = A_full.loc[selected_barcodes]
B_subset = B_full.loc[selected_barcodes]
C_subset = C_full.loc[selected_barcodes]

M_subset = M_df.loc[selected_barcodes]
M_subset.applymap(lambda x: round(x, 4))
Y_subset = Y_df.loc[selected_barcodes]
# Out:
# <ipython-input-98-d46252928dea>:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   M_subset.applymap(lambda x: round(x, 4))

# %%
def beta_mcmc(mu_hat, sigma_hat, a_prior, b_prior, c_prior, Y, BARCODE_list,
                nburn=500, nsamples=1000, nthin=1, **kwargs):
    np.set_printoptions(suppress=True, precision=2)
    print('Total BARCODEs:', len(BARCODE_list))

    Beta_samples = []
    Sigma_samples = []
    Loglikelihood_samples = []

    for barcode_idx, barcode in enumerate(BARCODE_list):
        print(f'Processing BARCODE {barcode} ({barcode_idx + 1} of {len(BARCODE_list)})')

        # Extract `a_prior`, `b_prior`, `c_prior`, and `Y` for the current BARCODE
        a = a_prior.loc[barcode, 'A']
        b = b_prior.loc[barcode, 'B']
        c = c_prior.loc[barcode, 'C']
        y_data = Y.loc[barcode].values

        print('a prior value: ', a,
              '\n b prior value: ', b,
              '\n c prior value: ', c,
              '\n intensity for this barcode: ', y_data)

        # Create lambda grid and weights for this BARCODE
        lam_grid = gamma.rvs(a=a, scale=b, size=100)  # Generate 100 lambda samples
        weights = gamma.pdf(lam_grid, a=a, scale=b)
        weights /= weights.sum()  # Normalize weights

        # Use the provided mu_hat and sigma_hat directly for the current BARCODE
        Mu = mu_hat[barcode_idx]  # Now accessing one BARCODE's mu_hat vector
        Sigma = sigma_hat  # Constant covariance matrix

        # Initialize Beta with Mu
        Beta = np.copy(Mu)

        # Prepare results arrays for this BARCODE
        barcode_Beta_samples = np.zeros((nsamples, len(Beta)))
        barcode_Sigma_samples = np.zeros((nsamples, Sigma.shape[0], Sigma.shape[1]))
        barcode_Loglikelihood_samples = np.zeros(nsamples)

        # Define log-likelihood function for the current BARCODE
        def log_likelihood(z):
            z = z[..., None]  # Expand for lambda grid
            lam = lam_grid[None, None]  # Room for z grid and multiple doses
            w = weights[None]
            y = y_data[None, :, None]
            result = np.nansum(np.log((poisson.pmf(y, ilogit(z) * lam + c) * w).clip(1e-10, np.inf).sum(axis=-1)), axis=-1)
            return result

        # Initialize log-likelihood for the initial Beta
        Cur_log_likelihood = log_likelihood(Beta)
        chol_Sigma = np.linalg.cholesky(Sigma)

        # Run MCMC sampling for this BARCODE
        for step in range(nburn + nsamples * nthin):
            print(f'MCMC step {step + 1}/{nburn + nsamples * nthin} for BARCODE {barcode}')

            # Apply elliptical slice sampling for Beta
            Beta, Cur_log_likelihood = elliptical_slice(
                Beta,
                chol_Sigma,               # Cholesky decomposition of Sigma
                log_likelihood,           # Log-likelihood function
                cur_log_like=Cur_log_likelihood,  # Current log likelihood
                mu=Mu                     # Mean vector for elliptical slice
            )

            # Save samples after burn-in and thinning
            if step >= nburn and ((step - nburn) % nthin) == 0:
                sample_idx = (step - nburn) // nthin
                barcode_Beta_samples[sample_idx] = Beta
                barcode_Sigma_samples[sample_idx] = Sigma
                barcode_Loglikelihood_samples[sample_idx] = Cur_log_likelihood

        # Store the samples for this BARCODE
        Beta_samples.append(barcode_Beta_samples)
        Sigma_samples.append(barcode_Sigma_samples)
        Loglikelihood_samples.append(barcode_Loglikelihood_samples)

    # Convert results to arrays
    Beta_samples = np.array(Beta_samples)
    Sigma_samples = np.array(Sigma_samples)
    Loglikelihood_samples = np.array(Loglikelihood_samples)

    return Beta_samples, Sigma_samples, Loglikelihood_samples

# %%
mu_hat = np.random.uniform(low=0.1, high=0.9, size=(len(selected_barcodes), 7))
mu_hat_df = pd.DataFrame(mu_hat, index=selected_barcodes, columns=[f"Dose_{i+1}" for i in range(mu_hat.shape[1])])

# Generate random sigma_hat as a constant covariance matrix (7x7) for dose levels
# Here, using a symmetric positive definite matrix
random_matrix = np.random.rand(7, 7)
sigma_hat = np.dot(random_matrix, random_matrix.T)  # Make it positive definite

# %%
B_s10, S_s10, LL_s10 = beta_mcmc(np.array(mu_hat_df), sigma_hat, A_subset, B_subset, C_subset, Y_subset, selected_barcodes,
          nburn = 500, nsamples = 1000, nthin=1)
# Out:
# Total BARCODEs: 30
# Processing BARCODE 25359 (1 of 30)
# a prior value:  54.82807322969456
#  b prior value:  565.3405903137269
#  c prior value:  498.0
#  intensity for this barcode:  [ 5255. 25084. 29911. 25801. 27617. 28477. 30771.]
# MCMC step 1/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 2/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 3/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 4/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 5/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 6/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 7/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 8/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 9/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 10/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 11/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 12/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 13/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 14/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 15/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 16/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 17/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 18/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 19/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 20/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 21/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 22/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 23/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 24/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 25/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 26/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 27/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 28/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 29/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 30/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 31/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 32/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 33/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 34/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 35/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 36/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 37/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 38/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 39/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 40/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 41/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 42/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 43/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 44/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 45/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 46/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 47/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 48/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 49/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 50/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 51/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 52/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 53/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 54/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 55/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 56/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 57/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 58/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 59/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 60/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 61/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 62/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 63/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 64/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 65/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 66/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 67/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 68/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 69/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 70/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 71/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 72/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 73/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 74/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 75/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 76/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 77/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 78/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 79/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 80/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 81/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 82/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 83/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 84/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 85/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 86/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 87/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 88/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 89/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 90/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 91/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 92/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 93/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 94/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 95/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 96/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 97/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 98/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 99/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 100/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 101/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 102/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 103/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 104/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 105/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 106/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 107/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 108/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 109/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 110/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 111/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 112/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 113/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 114/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 115/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 116/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 117/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 118/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 119/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 120/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 121/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 122/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 123/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 124/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 125/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 126/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 127/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 128/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 129/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 130/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 131/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 132/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 133/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 134/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 135/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 136/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 137/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 138/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 139/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 140/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 141/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 142/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 143/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 144/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 145/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 146/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 147/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 148/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 149/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 150/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 151/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 152/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 153/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 154/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 155/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 156/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 157/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 158/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 159/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 160/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 161/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 162/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 163/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 164/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 165/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 166/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 167/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 168/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 169/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 170/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 171/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 172/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 173/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 174/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 175/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 176/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 177/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 178/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 179/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 180/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 181/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 182/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 183/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 184/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 185/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 186/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 187/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 188/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 189/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 190/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 191/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 192/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 193/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 194/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 195/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 196/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 197/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 198/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 199/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 200/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 201/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 202/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 203/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 204/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 205/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 206/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 207/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 208/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 209/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 210/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 211/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 212/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 213/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 214/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 215/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 216/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 217/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 218/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 219/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 220/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 221/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 222/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 223/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 224/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 225/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 226/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 227/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 228/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 229/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 230/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 231/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 232/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 233/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 234/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 235/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 236/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 237/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 238/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 239/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 240/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 241/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 242/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 243/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 244/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 245/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 246/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 247/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 248/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 249/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 250/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 251/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 252/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 253/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 254/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 255/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 256/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 257/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 258/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 259/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 260/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 261/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 262/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 263/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 264/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 265/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 266/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 267/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 268/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 269/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 270/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 271/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 272/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 273/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 274/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 275/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 276/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 277/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 278/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 279/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 280/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 281/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 282/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 283/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 284/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 285/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 286/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 287/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 288/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 289/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 290/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 291/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 292/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 293/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 294/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 295/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 296/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 297/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 298/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 299/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 300/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 301/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 302/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 303/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 304/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 305/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 306/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 307/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 308/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 309/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 310/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 311/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 312/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 313/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 314/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 315/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 316/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 317/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 318/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 319/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 320/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 321/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 322/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 323/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 324/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 325/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 326/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 327/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 328/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 329/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 330/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 331/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 332/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 333/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 334/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 335/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 336/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 337/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 338/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 339/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 340/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 341/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 342/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 343/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 344/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 345/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 346/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 347/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 348/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 349/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 350/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 351/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 352/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 353/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 354/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 355/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 356/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 357/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 358/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 359/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 360/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 361/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 362/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 363/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 364/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 365/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 366/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 367/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 368/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 369/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 370/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 371/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 372/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 373/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 374/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 375/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 376/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 377/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 378/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 379/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 380/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 381/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 382/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 383/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 384/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 385/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 386/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 387/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 388/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 389/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 390/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 391/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 392/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 393/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 394/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 395/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 396/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 397/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 398/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 399/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 400/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 401/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 402/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 403/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 404/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 405/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 406/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 407/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 408/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 409/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 410/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 411/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 412/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 413/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 414/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 415/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 416/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 417/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 418/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 419/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 420/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 421/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 422/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 423/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 424/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 425/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 426/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 427/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 428/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 429/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 430/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 431/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 432/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 433/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 434/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 435/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 436/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 437/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 438/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 439/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 440/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 441/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 442/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 443/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 444/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 445/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 446/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 447/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 448/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 449/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 450/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 451/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 452/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 453/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 454/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 455/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 456/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 457/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 458/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 459/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 460/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 461/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 462/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 463/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 464/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 465/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 466/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 467/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 468/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 469/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 470/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 471/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 472/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 473/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 474/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 475/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 476/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 477/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 478/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 479/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 480/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 481/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 482/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 483/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 484/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 485/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 486/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 487/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 488/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 489/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 490/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 491/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 492/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 493/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 494/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 495/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 496/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 497/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 498/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 499/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 500/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 501/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 502/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 503/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 504/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 505/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 506/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 507/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 508/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 509/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 510/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 511/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 512/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 513/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 514/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 515/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 516/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 517/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 518/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 519/1500 for BARCODE 25359
# xx size:  (7,) prior size:  (7, 7)
# <ipython-input-99-be8a1a6257c3>:72: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   barcode_Loglikelihood_samples[sample_idx] = Cur_log_likelihood
# Streaming output truncated to the last 5000 lines.
# MCMC step 1336/1500 for BARCODE 18014
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1337/1500 for BARCODE 18014
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1338/1500 for BARCODE 18014
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1339/1500 for BARCODE 18014
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1340/1500 for BARCODE 18014
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1341/1500 for BARCODE 18014
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1342/1500 for BARCODE 18014
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1343/1500 for BARCODE 18014
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1344/1500 for BARCODE 18014
# xx size:  (7,) prior size:  (7, 7)
# ...
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1326/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1327/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1328/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1329/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1330/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1331/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1332/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1333/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1334/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1335/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1336/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1337/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1338/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1339/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1340/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1341/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1342/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1343/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1344/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1345/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1346/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1347/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1348/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1349/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1350/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1351/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1352/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1353/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1354/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1355/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1356/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1357/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1358/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1359/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1360/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1361/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1362/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1363/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1364/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1365/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1366/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1367/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1368/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1369/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1370/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1371/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1372/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1373/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1374/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1375/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1376/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1377/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1378/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1379/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1380/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1381/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1382/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1383/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1384/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1385/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1386/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1387/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1388/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1389/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1390/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1391/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1392/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1393/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1394/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1395/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1396/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1397/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1398/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1399/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1400/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1401/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1402/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1403/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1404/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1405/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1406/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1407/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1408/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1409/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1410/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1411/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1412/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1413/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1414/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1415/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1416/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1417/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1418/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1419/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1420/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1421/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1422/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1423/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1424/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1425/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1426/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1427/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1428/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1429/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1430/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1431/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1432/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1433/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1434/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1435/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1436/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1437/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1438/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1439/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1440/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1441/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1442/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1443/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1444/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1445/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1446/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1447/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1448/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1449/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1450/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1451/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1452/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1453/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1454/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1455/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1456/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1457/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1458/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1459/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1460/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1461/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1462/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1463/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1464/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1465/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1466/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1467/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1468/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1469/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1470/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1471/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1472/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1473/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1474/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1475/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1476/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1477/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1478/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1479/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1480/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1481/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1482/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1483/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1484/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1485/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1486/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1487/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1488/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1489/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1490/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1491/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1492/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1493/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1494/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1495/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1496/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1497/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1498/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1499/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta
# MCMC step 1500/1500 for BARCODE 19869
# xx size:  (7,) prior size:  (7, 7)
# Accepted new beta

# %%
selected_barcodes
# Out:
# array([25359, 58466, 20650, 12540, 48211, 22743, 12717, 62918, 13319,
#        44390, 29732, 11454, 15880, 11558, 24388, 62462, 38511, 51347,
#        16465, 43846, 20918, 49777, 24162, 29021, 45867, 42030, 15970,
#        10573, 18014, 19869])

# %%
Tau_s10 = ilogit(B_s10)

# %%
def get_cell_line_and_drug_name(barcode):
    result = raw_data[raw_data['BARCODE'] == barcode]
    if not result.empty:
      cell_line_name = result.iloc[0]['CELL_LINE_NAME']
      drug_name = result.iloc[0]['DRUG_ID']
      return cell_line_name, drug_name
    else:
      return None, None

# %%
for i in range(len(selected_barcodes)):
    barcode = selected_barcodes[i]
    cell_line, drug = get_cell_line_and_drug_name(barcode)
    print(f"BARCODE: {barcode} - Cell line: {cell_line}, Drug: {drug}")
# Out:
# BARCODE: 25359 - Cell line: HCC-78, Drug: nan
# BARCODE: 58466 - Cell line: Caov-4, Drug: nan
# BARCODE: 20650 - Cell line: SNU-C5, Drug: nan
# BARCODE: 12540 - Cell line: PC-14, Drug: nan
# BARCODE: 48211 - Cell line: DAN-G, Drug: nan
# BARCODE: 22743 - Cell line: SW1573, Drug: nan
# BARCODE: 12717 - Cell line: C-4-I, Drug: nan
# BARCODE: 62918 - Cell line: SU8686, Drug: nan
# BARCODE: 13319 - Cell line: EW-1, Drug: nan
# BARCODE: 44390 - Cell line: 769-P, Drug: nan
# BARCODE: 29732 - Cell line: LC-1-sq, Drug: nan
# BARCODE: 11454 - Cell line: SK-LU-1, Drug: nan
# BARCODE: 15880 - Cell line: AU565, Drug: nan
# BARCODE: 11558 - Cell line: PC-14, Drug: nan
# BARCODE: 24388 - Cell line: U-2-OS, Drug: nan
# BARCODE: 62462 - Cell line: HuP-T3, Drug: nan
# BARCODE: 38511 - Cell line: MZ1-PC, Drug: nan
# BARCODE: 51347 - Cell line: IM-95, Drug: nan
# BARCODE: 16465 - Cell line: COLO-680N, Drug: nan
# BARCODE: 43846 - Cell line: HT-29, Drug: nan
# BARCODE: 20918 - Cell line: SW948, Drug: nan
# BARCODE: 49777 - Cell line: SK-ES-1, Drug: nan
# BARCODE: 24162 - Cell line: CL-11, Drug: nan
# BARCODE: 29021 - Cell line: LS-513, Drug: nan
# BARCODE: 45867 - Cell line: NCI-H2452, Drug: nan
# BARCODE: 42030 - Cell line: HCC1569, Drug: nan
# BARCODE: 15970 - Cell line: UACC-893, Drug: nan
# BARCODE: 10573 - Cell line: SW1088, Drug: nan
# BARCODE: 18014 - Cell line: SW48, Drug: nan
# BARCODE: 19869 - Cell line: MHH-ES-1, Drug: nan

# %%
import matplotlib
with sns.axes_style('white', {'legend.frameon': True}):
    plt.rc('font', weight='bold')
    plt.rc('grid', lw=3)
    plt.rc('lines', lw=1)
    matplotlib.rcParams['pdf.fonttype'] = 42
    matplotlib.rcParams['ps.fonttype'] = 42
    plt.plot(Tau_s10[:, :10, 0].reshape((Tau_s10.shape[0], -1)))
    plt.xlabel('MCMC iteration', fontsize=18)
    plt.ylabel('Dose-response values ($\\tau$)', fontsize=18)
    plt.savefig(f'/content/trace-{drug}.pdf', bbox_inches='tight')
    plt.close()

# %%
barcode_idx = 0
dose_idx = 0

plt.figure(figsize=(10, 6))
plt.plot(B_s10[barcode_idx, :, dose_idx], label=f"BARCODE {selected_barcodes[barcode_idx]}, Dose {dose_idx+1}")
plt.xlabel("MCMC Iteration")
plt.ylabel("Beta Value")
plt.title(f"Trace Plot for Beta (BARCODE {selected_barcodes[barcode_idx]}, Dose {dose_idx+1})")
plt.legend()
plt.show()

plt.figure(figsize=(8, 6))
sns.histplot(B_s10[barcode_idx, :, dose_idx], kde=True)
plt.xlabel("Beta Value")
plt.ylabel("Density")
plt.title(f"Posterior Distribution of Beta (BARCODE {selected_barcodes[barcode_idx]}, Dose {dose_idx+1})")
plt.show()
